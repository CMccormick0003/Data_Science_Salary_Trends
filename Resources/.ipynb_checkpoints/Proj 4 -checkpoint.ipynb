# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# use logistic regression for the model

# %%
df_refined = pd.read_csv("./DSRoles_US_2023.csv")
df_refined.drop('Unnamed: 0', inplace=True, axis=1)
df_refined
# Out:
#       employment_type_code experience_level_code job category code  \
# 0                        1                     2                 3
# 1                        1                     2                 3
# 2                        2                     3                 8
# 3                        2                     3                 8
# 4                        2                     3                 5
# ...                    ...                   ...               ...
# 1560                     2                     3                 3
# 1561                     2                     2                 5
# 1562                     2                     2                 5
# 1563                     2                     1                 3
# 1564                     2                     1                 3
#
#      salary_in_usd_code  company_size_code  remote_ratio
# 0                     1                  1           100
# ...

# %%
# import data
df = pd.read_csv("ds_salaries.csv")
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
# all column name
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df = df.loc[df["job_title"].isin(['Data Scientist', 'Data Engineer','Data Analyst'])]
df
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 3          2023               SE              FT  Data Scientist  175000
# 4          2023               SE              FT  Data Scientist  120000
# 7          2023               SE              FT  Data Scientist  219000
# 8          2023               SE              FT  Data Scientist  141000
# 9          2023               SE              FT  Data Scientist  147100
# ...         ...              ...             ...             ...     ...
# 3743       2020               MI              FT   Data Engineer  130800
# 3746       2021               MI              FT  Data Scientist  160000
# 3748       2021               MI              FT   Data Engineer   24000
# 3750       2020               SE              FT  Data Scientist  412000
# 3752       2020               EN              FT  Data Scientist  105000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df = df.loc[df["employment_type"].isin(['FT', 'CT','PT'])]
df
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 3          2023               SE              FT  Data Scientist  175000
# 4          2023               SE              FT  Data Scientist  120000
# 7          2023               SE              FT  Data Scientist  219000
# 8          2023               SE              FT  Data Scientist  141000
# 9          2023               SE              FT  Data Scientist  147100
# ...         ...              ...             ...             ...     ...
# 3743       2020               MI              FT   Data Engineer  130800
# 3746       2021               MI              FT  Data Scientist  160000
# 3748       2021               MI              FT   Data Engineer   24000
# 3750       2020               SE              FT  Data Scientist  412000
# 3752       2020               EN              FT  Data Scientist  105000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df = df.loc[df["work_year"] == 2023]
df
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 3          2023               SE              FT  Data Scientist  175000
# 4          2023               SE              FT  Data Scientist  120000
# 7          2023               SE              FT  Data Scientist  219000
# 8          2023               SE              FT  Data Scientist  141000
# 9          2023               SE              FT  Data Scientist  147100
# ...         ...              ...             ...             ...     ...
# 1813       2023               MI              FT    Data Analyst  100000
# 1817       2023               MI              FT  Data Scientist  130000
# 1818       2023               MI              FT  Data Scientist   90000
# 1819       2023               EN              FT   Data Engineer  160000
# 1820       2023               EN              FT   Data Engineer  135000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df.drop('salary', inplace=True, axis=1)
df
# Out:
# C:\Users\Aaron\AppData\Local\Temp\ipykernel_26596\1638544445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('salary', inplace=True, axis=1)
#       work_year experience_level employment_type       job_title  \
# 3          2023               SE              FT  Data Scientist
# 4          2023               SE              FT  Data Scientist
# 7          2023               SE              FT  Data Scientist
# 8          2023               SE              FT  Data Scientist
# 9          2023               SE              FT  Data Scientist
# ...         ...              ...             ...             ...
# 1813       2023               MI              FT    Data Analyst
# 1817       2023               MI              FT  Data Scientist
# ...

# %%
df.drop('salary_currency', inplace=True, axis=1)
# Out:
# C:\Users\Aaron\AppData\Local\Temp\ipykernel_26596\3437703937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('salary_currency', inplace=True, axis=1)

# %%
df
# Out:
#       work_year experience_level employment_type       job_title  \
# 3          2023               SE              FT  Data Scientist
# 4          2023               SE              FT  Data Scientist
# 7          2023               SE              FT  Data Scientist
# 8          2023               SE              FT  Data Scientist
# 9          2023               SE              FT  Data Scientist
# ...         ...              ...             ...             ...
# 1813       2023               MI              FT    Data Analyst
# 1817       2023               MI              FT  Data Scientist
# 1818       2023               MI              FT  Data Scientist
# 1819       2023               EN              FT   Data Engineer
# 1820       2023               EN              FT   Data Engineer
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 3            175000                 CA           100               CA
# ...

# %%
df.drop('employee_residence', inplace=True, axis=1)
df
# Out:
# C:\Users\Aaron\AppData\Local\Temp\ipykernel_26596\3959178920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('employee_residence', inplace=True, axis=1)
#       work_year experience_level employment_type       job_title  \
# 3          2023               SE              FT  Data Scientist
# 4          2023               SE              FT  Data Scientist
# 7          2023               SE              FT  Data Scientist
# 8          2023               SE              FT  Data Scientist
# 9          2023               SE              FT  Data Scientist
# ...         ...              ...             ...             ...
# 1813       2023               MI              FT    Data Analyst
# 1817       2023               MI              FT  Data Scientist
# ...

# %%
df = df.loc[df["company_location"].isin(['US'])]
df
# Out:
#       work_year experience_level employment_type       job_title  \
# 9          2023               SE              FT  Data Scientist
# 10         2023               SE              FT  Data Scientist
# 11         2023               SE              FT    Data Analyst
# 12         2023               SE              FT    Data Analyst
# 17         2023               SE              FT  Data Scientist
# ...         ...              ...             ...             ...
# 1813       2023               MI              FT    Data Analyst
# 1817       2023               MI              FT  Data Scientist
# 1818       2023               MI              FT  Data Scientist
# 1819       2023               EN              FT   Data Engineer
# 1820       2023               EN              FT   Data Engineer
#
#       salary_in_usd  remote_ratio company_location company_size
# 9            147100             0               US            M
# ...

# %%
X = df[["experience_level","employment_type", "job_title", "remote_ratio", "company_size"]]
y = df["salary_in_usd"]

# %%
X
# Out:
#      experience_level employment_type       job_title  remote_ratio  \
# 9                  SE              FT  Data Scientist             0
# 10                 SE              FT  Data Scientist             0
# 11                 SE              FT    Data Analyst           100
# 12                 SE              FT    Data Analyst           100
# 17                 SE              FT  Data Scientist             0
# ...               ...             ...             ...           ...
# 1813               MI              FT    Data Analyst             0
# 1817               MI              FT  Data Scientist             0
# 1818               MI              FT  Data Scientist             0
# 1819               EN              FT   Data Engineer             0
# 1820               EN              FT   Data Engineer             0
#
#      company_size
# 9               M
# 10              M
# 11              M
# 12              M
# 17              M
# ...           ...
# ...

# %%
dummies = pd.get_dummies(X, columns = ['experience_level', 'employment_type', 'job_title', 'company_size'], drop_first = False)

# %%
X=X.drop(['experience_level', 'employment_type', 'job_title', 'company_size'], axis = 1)

# %%
X = pd.concat([X, dummies], axis = 1)

# %%
X
# Out:
#       remote_ratio  remote_ratio  experience_level_EN  experience_level_EX  \
# 9                0             0                    0                    0
# 10               0             0                    0                    0
# 11             100           100                    0                    0
# 12             100           100                    0                    0
# 17               0             0                    0                    0
# ...            ...           ...                  ...                  ...
# 1813             0             0                    0                    0
# 1817             0             0                    0                    0
# 1818             0             0                    0                    0
# 1819             0             0                    1                    0
# 1820             0             0                    1                    0
#
# ...

# %%
# split data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
# instantiate 
model = LinearRegression()
# fit
model.fit(X_train, y_train)
# predict
y_pred = model.predict(X_test)

# %%
# model evaluation
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.24258747812850123
